# %% [markdown]
# **Linear Regression**

# %% [markdown]
# ![linear.png](data:image/png;base64,...)

# %% [markdown]
# Salarydata ---> dataset used

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
dataset = pd.read_csv('/content/salaryData.csv')
dataset.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
dataset.shape
# Out:
# (30, 2)

# %%
dataset.columns
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 608.0 bytes

# %%
dataset.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
dataset.iloc[2:6]         #certain rows in the dataset
# Out:
#    YearsExperience   Salary
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0
# 5              2.9  56642.0

# %%
dataset.corr()          # correlation (relation of one feature with other feature)
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.978242
# Salary                  0.978242  1.000000

# %%
dataset.nunique()
# Out:
# YearsExperience    28
# Salary             30
# dtype: int64

# %%
x=dataset['YearsExperience']
y=dataset['Salary']
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.scatter(x,y,color = 'red',marker='*')
plt.show()

# %%
# since it accepts 2d data so we need to reshape the data

# %% [markdown]
# Splitting of data

# %%
x=dataset.iloc[:,:-1].values             # iloc is used to access elements in dataframe
y=dataset.iloc[:,1].values
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=1/3,random_state=1)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (20, 1)
# (10, 1)
# (20,)
# (10,)

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-4f30f9ee332f> in <module>()
# ----> 1 model = LinearRegression()
#       2 model.fit(x_train,y_train)
#
# NameError: name 'LinearRegression' is not defined

# %%
y_test_predict = model.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-eb7e2f8c1b1c> in <module>()
# ----> 1 y_test_predict = model.predict(x_test)
#
# NameError: name 'model' is not defined

# %%
y_test_predict
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-40d248bda63b> in <module>()
# ----> 1 y_test_predict
#
# NameError: name 'y_test_predict' is not defined

# %%
from sklearn.metrics import mean_squared_error,r2_score
mse = mean_squared_error(y_test, y_test_predict)
r2 = r2_score(y_test,y_test_predict)
print(r2)
print(mse)

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(model,x_train,y_train,scoring='neg_mean_squared_error',cv=7)
rmse = np.sqrt(-scores)
rmse

# %%
rmse.mean()

# %% [markdown]
# **saving the model**

# %% [markdown]
# *using joblib*

# %%
import joblib
file = "salary.sav"
joblib.dump(model , file)
# Out:
# ['salary.sav']

# %%
data = (7)
input_data = np.asarray(data)
input_data_reshape = input_data.reshape(1,-1)
new_model = joblib.load('salary.sav')
predict = new_model.predict(input_data_reshape)
predict
# Out:
# array([90244.21440532])

# %%
model.predict([[9]])
# Out:
# array([108560.49280278])

# %% [markdown]
#  *using pickle*

# %%
import pickle

# %%
filename = model_Gradient
with open(filename,'wb') as file:
  pickle.dump(model,file)

# %%
with open('model_Gradient','rb') as file:
  newmodel = pickle.load(file)
newmodel.predict(data)

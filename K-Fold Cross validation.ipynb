# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.datasets import load_iris
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

# %%
data = load_iris()

# %%
x = data.data
y = data.target

# %% [markdown]
# **Logistic Regression**

# %%
lr_score = cross_val_score(LogisticRegression(),x,y)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
lr_score
# Out:
# array([0.96666667, 1.        , 0.93333333, 0.96666667, 1.        ])

# %%
lr_score = np.average(lr_score)
lr_score
# Out:
# 0.9733333333333334

# %% [markdown]
# **Decision Tree**

# %%
Dt_score = cross_val_score(DecisionTreeClassifier(),x,y)

# %%
Dt_score
# Out:
# array([0.96666667, 0.96666667, 0.9       , 1.        , 1.        ])

# %%
Dt_score = np.average(Dt_score)

# %%
Dt_score
# Out:
# 0.9666666666666668

# %% [markdown]
# **Support Vector Machine**

# %%
svc_score = cross_val_score(SVC(),x,y)

# %%
svc_score
# Out:
# array([0.96666667, 0.96666667, 0.96666667, 0.93333333, 1.        ])

# %%
svc_score = np.average(svc_score)

# %%
svc_score
# Out:
# 0.9666666666666666

# %% [markdown]
# ***From above score we could find the best model***

# %% [markdown]
# As in above case Logistic Regression has high accuracy so it is the best model for iris_data
